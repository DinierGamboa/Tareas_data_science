# %% [markdown]
# # Tarea 1 - Pandas y Matplotlib
#
# - Utilizando los datos de exoplanetas de la Sesión 2, haga lo siguiente
# 1. Cree un nuevo dataframe
# 2. Utilice el groupby para agrupar los planetas por su método de descubrimiento.
# 3. Utilizando un groupby().agg(), agrupe los planetas por su método de descubrimiento, y agreguelos por sus masas.
# 4. Cree un gráfico de barras donde cada barra sea uno de los métodos de descubrimiento, y el eje y sea el total de las masas de los planetas descubiertos por ese método.

# %% [markdown]
# <img src='Tarea1.png' width=400>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

kepler = pd.read_csv('oec.csv')
pd.set_option('display.max_columns', None)
#pd.reset_option('max_columns')
kepler.head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      HD 143761 b         0            1.0450        NaN   39.845800
# 1      HD 143761 c         0            0.0790        NaN  102.540000
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.2196         0.037          270.6           NaN
# 1           0.4123         0.050          190.0           NaN
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 0               NaN             NaN           NaN     NaN              RV
# ...

# %% [markdown]
# Acá vendrán los planetas asignados en diferentes grupos, donde cada grupo corresponde a un único método de descubrimiento.
# Se mostrarán tres planetas por grupo para más comodidad pero se puede manipular la cantidad que se desea ver agregando el valor que guste dentro de head( )

# %% [markdown]
# Los grupos designados con las variables 'a', 'b', 'c', 'd' y 'e' corresponden a planetas descubiertos por el método de transit, RV, imaging, microlensing y timing respectivamente.

# %%
a = kepler.groupby(['DiscoveryMethod']).get_group('transit')

a.head(3)
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 2               NaN           72.00           NaN     NaN         transit
# 3               NaN           89.38           NaN     NaN         transit
# 4               NaN           88.24           NaN     NaN         transit
#
#    DiscoveryYear LastUpdated RightAscension  Declination  DistFromSunParsec  \
# ...

# %%
b = kepler.groupby(['DiscoveryMethod']).get_group('RV')

b.head(3)
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      HD 143761 b         0            1.0450        NaN     39.8458
# 1      HD 143761 c         0            0.0790        NaN    102.5400
# 8       GJ 160.2 b         0            0.0321        NaN      5.2354
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.2196         0.037          270.6           NaN
# 1           0.4123         0.050          190.0           NaN
# 8           0.0530         0.060          350.0           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 0               NaN             NaN           NaN     NaN              RV
# 1               NaN             NaN           NaN     NaN              RV
# 8               NaN             NaN           NaN     NaN              RV
#
#    DiscoveryYear LastUpdated  RightAscension     Declination  \
# 0         2016.0    16/07/11        16 01 03       +33 18 13
# ...

# %%
c = kepler.groupby(['DiscoveryMethod']).get_group('imaging')

c.head(3)
# Out:
#       PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 190          CVSO 30 c         0               4.7       1.63         NaN
# 237          CHXR 73 b         0              12.0        NaN         NaN
# 307  2MASS 0122-2439 B         0               NaN        NaN         NaN
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 190            662.0           NaN            NaN           NaN
# 237              NaN           NaN            NaN           NaN
# 307              NaN           NaN            NaN           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 190               NaN             NaN        1600.0     NaN         imaging
# 237               NaN             NaN           NaN     NaN         imaging
# 307               NaN             NaN           NaN     NaN         imaging
#
#      DiscoveryYear LastUpdated RightAscension   Declination  \
# ...

# %%
d = kepler.groupby(['DiscoveryMethod']).get_group('microlensing')

d.head(3)
# Out:
#          PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 12         OGLE-05-390L b         0             0.017        NaN      3500.0
# 242          KMT-2015-1 b         0             2.200        NaN         NaN
# 370  MOA-2007-BLG-400-L b         0             0.900        NaN         NaN
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 12              2.10           NaN            NaN           NaN
# 242              NaN           NaN            NaN           NaN
# 370             0.85           NaN            NaN           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 12                NaN             NaN           NaN     NaN    microlensing
# 242               NaN             NaN           NaN     NaN    microlensing
# 370               NaN             NaN         104.6     NaN    microlensing
#
#      DiscoveryYear LastUpdated RightAscension  Declination  DistFromSunParsec  \
# ...

# %%
e=kepler.groupby('DiscoveryMethod').get_group('timing')

e.head(3)
# Out:
#        PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 259  NY Virginis (AB) b         1            2.3000        NaN     2900.00
# 261       HW Vir (AB) b         1           14.3000        NaN     4640.00
# 501           KOI-372 c         0            0.3194        NaN      463.44
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 259             3.30           NaN            NaN           NaN
# 261             4.69        0.4000            NaN           NaN
# 501              NaN        0.1701         178.88           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 259               NaN             NaN           NaN     NaN          timing
# 261               NaN             NaN           NaN     NaN          timing
# 501               NaN           91.78           NaN     NaN          timing
#
#      DiscoveryYear LastUpdated  RightAscension     Declination  \
# ...

# %% [markdown]
# Ahora usando la función agg() tomaremos las masas de los planetas y las sumaremos, esto por cada uno de los grupos:

# %% [markdown]
# Transit:

# %%
a1 = a.agg('PlanetaryMassJpt').sum()
a1
# Out:
# 572.6871405734178

# %%
a1 = a.agg('PlanetaryMassJpt')
a11 = pd.DataFrame(a1)
a11
# Out:
#       PlanetaryMassJpt
# 2               0.0014
# 3                  NaN
# 4                  NaN
# 5               0.2500
# 6               0.1700
# ...                ...
# 3574            4.0630
# 3575               NaN
# 3577            3.3280
# 3578               NaN
# 3583               NaN
#
# [2712 rows x 1 columns]

# %% [markdown]
# RV:

# %%
b1 = b.agg('PlanetaryMassJpt').sum()
b1
# Out:
# 2234.6427669831

# %% [markdown]
# Imaging:

# %%
c1 = c.agg('PlanetaryMassJpt').sum()
c1
# Out:
# 601.6035

# %% [markdown]
# Microlensing:

# %%
d1 = d.agg('PlanetaryMassJpt').sum()
d1
# Out:
# 73.603112615497

# %% [markdown]
# Timing:

# %%
e1 = e.agg('PlanetaryMassJpt').sum()
e1
# Out:
# 175.4232629

# %% [markdown]
# Ahora haremos gráfico de barras ploteando en el eje x los Métodos de descubrimiento y en el eje y el valor de las masas sumadas por cada método

# %%
x = np.array(['transit', 'RV', 'imaging', 'microlensing', 'timing'])
y = np.array([a1, b1, c1, d1, e1])

plt.bar(x, y, color = ['red', 'orange', 'yellow', 'green', 'blue'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Como extra me dio curiosidad saber cuantos valores tiene cada uno de los grupos, y compararlo con las barras del gráfico:

# %%
kepler['DiscoveryMethod'].value_counts()
# Out:
# transit         2712
# RV               692
# imaging           52
# microlensing      40
# timing            25
# Name: DiscoveryMethod, dtype: int64

# %% [markdown]
# Como veo que hay más valores en el grupo 'Transit' que en el de 'RV', siendo este el que tiene una suma mayor, me dio curiosidad por saber como se distribuyen los valores de masa por cada grupo:

# %%
kepler.groupby('DiscoveryMethod')['PlanetaryMassJpt'].value_counts()
# Out:
# DiscoveryMethod  PlanetaryMassJpt
# RV               2.000000            7
#                  1.500000            6
#                  1.900000            6
#                  1.600000            5
#                  1.800000            5
#                  2.300000            5
#                  0.330000            4
#                  0.360000            4
#                  0.480000            4
#                  0.620000            4
#                  1.400000            4
#                  1.700000            4
#                  2.100000            4
#                  2.700000            4
#                  3.000000            4
#                  0.020000            3
#                  0.036000            3
#                  0.058000            3
#                  0.340000            3
#                  0.460000            3
#                  0.540000            3
#                  0.820000            3
#                  0.960000            3
# ...

# %% [markdown]
# Al revisar de forma rápida se nota que hay aprox. igual o más valores númericos para RV que para transit, a pesar de que Transit es quién se registra más veces en la columna de Métodos de descubrimiento. En conclusión esto muestra que hay una gran cantidad de datos faltantes de masa con el método de Transit
