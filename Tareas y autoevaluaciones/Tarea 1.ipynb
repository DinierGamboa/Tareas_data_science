# %% [markdown]
# # Tarea 1 - Pandas y Matplotlib
#
# - Utilizando los datos de exoplanetas de la Sesión 2, haga lo siguiente
# 1. Cree un nuevo dataframe
# 2. Utilice el groupby para agrupar los planetas por su método de descubrimiento.
# 3. Utilizando un groupby().agg(), agrupe los planetas por su método de descubrimiento, y agreguelos por sus masas.
# 4. Cree un gráfico de barras donde cada barra sea uno de los métodos de descubrimiento, y el eje y sea el total de las masas de los planetas descubiertos por ese método.

# %% [markdown]
# <img src='Tarea1.png' width=400>

# %%
import pandas as pd
import matplotlib.pyplot as plt

kepler = pd.read_csv('oec.csv')
pd.set_option('display.max_columns', None)
#pd.reset_option('max_columns')
kepler.head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      HD 143761 b         0            1.0450        NaN   39.845800
# 1      HD 143761 c         0            0.0790        NaN  102.540000
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.2196         0.037          270.6           NaN
# 1           0.4123         0.050          190.0           NaN
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 0               NaN             NaN           NaN     NaN              RV
# 1               NaN             NaN           NaN     NaN              RV
# 2               NaN           72.00           NaN     NaN         transit
# 3               NaN           89.38           NaN     NaN         transit
# 4               NaN           88.24           NaN     NaN         transit
#
#    DiscoveryYear LastUpdated RightAscension  Declination  DistFromSunParsec  \
# 0         2016.0    16/07/11       16 01 03    +33 18 13             17.236
# 1         2016.0    16/07/11       16 01 03    +33 18 13             17.236
# 2         2012.0    13/07/15    19 00 03.14  +40 13 14.7                NaN
# 3            NaN         NaN    19 00 03.14  +40 13 14.7                NaN
# 4            NaN         NaN    19 00 03.14  +40 13 14.7                NaN
#
#    HostStarMassSlrMass  HostStarRadiusSlrRad  HostStarMetallicity  \
# 0                0.889                 1.362                -0.31
# 1                0.889                 1.362                -0.31
# 2                0.460                 0.450                 0.00
# 3                0.460                 0.450                 0.00
# 4                0.460                 0.450                 0.00
#
#    HostStarTempK  HostStarAgeGyr    ListsPlanetIsOn
# 0         5627.0             NaN  Confirmed planets
# 1         5627.0             NaN  Confirmed planets
# 2         3584.0             NaN      Controversial
# 3         3584.0             NaN      Controversial
# 4         3584.0             NaN      Controversial

# %%
kepler['DiscoveryMethod'].value_counts()
# Out:
# transit         2712
# RV               692
# imaging           52
# microlensing      40
# timing            25
# Name: DiscoveryMethod, dtype: int64

# %%
discov1=kepler.groupby(['DiscoveryMethod'])
discov1.get_group('transit').head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
# 5       Kepler-9 b         0            0.2500      0.840   19.224180
# 6       Kepler-9 c         0            0.1700      0.820   39.031060
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
# 5           0.1430        0.0626            NaN           NaN
# 6           0.2290        0.0684            NaN           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 2               NaN           72.00           NaN     NaN         transit
# 3               NaN           89.38           NaN     NaN         transit
# 4               NaN           88.24           NaN     NaN         transit
# 5               NaN           87.10         707.2     NaN         transit
# 6               NaN           87.20         557.9     NaN         transit
#
#    DiscoveryYear LastUpdated RightAscension  Declination  DistFromSunParsec  \
# 2         2012.0    13/07/15    19 00 03.14  +40 13 14.7                NaN
# 3            NaN         NaN    19 00 03.14  +40 13 14.7                NaN
# 4            NaN         NaN    19 00 03.14  +40 13 14.7                NaN
# 5         2010.0    15/12/03       19 02 17    +38 24 03              650.0
# 6         2010.0    15/12/03       19 02 17    +38 24 03              650.0
#
#    HostStarMassSlrMass  HostStarRadiusSlrRad  HostStarMetallicity  \
# 2                 0.46                  0.45                 0.00
# 3                 0.46                  0.45                 0.00
# 4                 0.46                  0.45                 0.00
# 5                 1.07                  1.02                 0.12
# 6                 1.07                  1.02                 0.12
#
#    HostStarTempK  HostStarAgeGyr    ListsPlanetIsOn
# 2         3584.0             NaN      Controversial
# 3         3584.0             NaN      Controversial
# 4         3584.0             NaN      Controversial
# 5         5777.0             NaN  Confirmed planets
# 6         5777.0             NaN  Confirmed planets

# %%
discov2=kepler.groupby(['DiscoveryMethod'])
discov2.get_group('RV').head()
# Out:
#    PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0       HD 143761 b         0            1.0450        NaN     39.8458
# 1       HD 143761 c         0            0.0790        NaN    102.5400
# 8        GJ 160.2 b         0            0.0321        NaN      5.2354
# 11      HD 240210 b         0            5.2100        NaN    501.7500
# 19        HD 4203 b         0            1.8200        NaN    437.0500
#
#     SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0            0.2196         0.037         270.60           NaN
# 1            0.4123         0.050         190.00           NaN
# 8            0.0530         0.060         350.00           NaN
# 11           1.3300         0.150         277.59           NaN
# 19           1.1735         0.520            NaN           NaN
#
#     AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 0                NaN             NaN           NaN     NaN              RV
# 1                NaN             NaN           NaN     NaN              RV
# 8                NaN             NaN           NaN     NaN              RV
# 11               NaN             NaN           NaN     NaN              RV
# 19               NaN             NaN         263.9     NaN              RV
#
#     DiscoveryYear LastUpdated  RightAscension     Declination  \
# 0          2016.0    16/07/11        16 01 03       +33 18 13
# 1          2016.0    16/07/11        16 01 03       +33 18 13
# 8          2014.0    15/04/21  04 06 34.84136  -20 51 11.2391
# 11         2009.0    15/11/26   23 10 29.2303   +57 01 46.035
# 19         2001.0    14/03/11        00 44 41       +20 26 56
#
#     DistFromSunParsec  HostStarMassSlrMass  HostStarRadiusSlrRad  \
# 0              17.236                0.889                 1.362
# 1              17.236                0.889                 1.362
# 8              43.250                0.690                   NaN
# 11            143.000                0.820                   NaN
# 19             77.820                1.130                 1.330
#
#     HostStarMetallicity  HostStarTempK  HostStarAgeGyr    ListsPlanetIsOn
# 0                -0.310         5627.0             NaN  Confirmed planets
# 1                -0.310         5627.0             NaN  Confirmed planets
# 8                   NaN         4347.0             NaN      Controversial
# 11               -0.180         4297.0             NaN  Confirmed planets
# 19                0.453         5702.0             NaN  Confirmed planets

# %%
discov3=kepler.groupby(['DiscoveryMethod'])
discov3.get_group('imaging').head()
# Out:
#       PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 190          CVSO 30 c         0               4.7       1.63         NaN
# 237          CHXR 73 b         0              12.0        NaN         NaN
# 307  2MASS 0122-2439 B         0               NaN        NaN         NaN
# 368           HN Peg b         0              22.0       1.05         NaN
# 369       CFBDS 1458 b         0               6.5        NaN      9855.0
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 190            662.0           NaN            NaN           NaN
# 237              NaN           NaN            NaN           NaN
# 307              NaN           NaN            NaN           NaN
# 368              NaN           NaN            NaN           NaN
# 369              2.6           NaN            NaN           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 190               NaN             NaN        1600.0     NaN         imaging
# 237               NaN             NaN           NaN     NaN         imaging
# 307               NaN             NaN           NaN     NaN         imaging
# 368               NaN             NaN        1130.0     NaN         imaging
# 369               NaN             NaN           NaN     NaN         imaging
#
#      DiscoveryYear LastUpdated RightAscension   Declination  \
# 190         2016.0    16/06/12       05 25 08     +01 34 24
# 237         2006.0    11/03/08       11 06 29     -77 37 33
# 307         2013.0    15/04/20   01 22 50.938  -24 39 50.65
# 368         2007.0    11/04/23       21 44 31     +14 46 19
# 369         2011.0    11/03/08       14 58 29     +10 13 43
#
#      DistFromSunParsec  HostStarMassSlrMass  HostStarRadiusSlrRad  \
# 190              330.0                 0.39                  1.39
# 237                NaN                 0.35                   NaN
# 307               36.0                 0.40                   NaN
# 368               18.4                 1.00                   NaN
# 369               23.1                 0.02                   NaN
#
#      HostStarMetallicity  HostStarTempK  HostStarAgeGyr    ListsPlanetIsOn
# 190                  NaN         3740.0         0.00265  Confirmed planets
# 237                  NaN         3840.0             NaN  Confirmed planets
# 307                  NaN            NaN         0.12000  Confirmed planets
# 368                  NaN         5940.0             NaN  Confirmed planets
# 369                  NaN          540.0             NaN  Confirmed planets

# %%
discov4=kepler.groupby(['DiscoveryMethod'])
discov4.get_group('microlensing').head()
# Out:
#          PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 12         OGLE-05-390L b         0             0.017        NaN      3500.0
# 242          KMT-2015-1 b         0             2.200        NaN         NaN
# 370  MOA-2007-BLG-400-L b         0             0.900        NaN         NaN
# 430   MOA-2008-BLG-379L b         0             4.100        NaN         NaN
# 471   MOA-2010-BLG-353L b         0             0.230        NaN         NaN
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 12              2.10           NaN            NaN           NaN
# 242              NaN           NaN            NaN           NaN
# 370             0.85           NaN            NaN           NaN
# 430             3.30           NaN            NaN           NaN
# 471              NaN           NaN            NaN           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 12                NaN             NaN           NaN     NaN    microlensing
# 242               NaN             NaN           NaN     NaN    microlensing
# 370               NaN             NaN         104.6     NaN    microlensing
# 430               NaN             NaN           NaN     NaN    microlensing
# 471               NaN             NaN           NaN     NaN    microlensing
#
#      DiscoveryYear LastUpdated RightAscension   Declination  \
# 12          2005.0    06/04/12       17 54 19     -30 22 38
# 242         2015.0    15/07/22    17 58 39.01   -28 01 54.1
# 370         2008.0    10/12/06       18 09 42     -29 13 27
# 430         2013.0    14/04/18       17 58 49     -30 11 49
# 471         2015.0    15/12/11    18 05 12.94  -27 17 35.64
#
#      DistFromSunParsec  HostStarMassSlrMass  HostStarRadiusSlrRad  \
# 12              6500.0                 0.22                   NaN
# 242             8200.0                 0.18                   NaN
# 370             6000.0                 0.35                   NaN
# 430             3300.0                 0.56                   NaN
# 471             7170.0                 0.16                   NaN
#
#      HostStarMetallicity  HostStarTempK  HostStarAgeGyr    ListsPlanetIsOn
# 12                   NaN         3840.0             NaN  Confirmed planets
# 242                  NaN            NaN             NaN  Confirmed planets
# 370                  NaN         5700.0             NaN  Confirmed planets
# 430                  NaN            NaN             NaN  Confirmed planets
# 471                  NaN            NaN             NaN  Confirmed planets

# %%
discov5=kepler.groupby(['DiscoveryMethod'])
discov5.get_group('timing').head()
# Out:
#        PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 259  NY Virginis (AB) b         1            2.3000        NaN     2900.00
# 261       HW Vir (AB) b         1           14.3000        NaN     4640.00
# 501           KOI-372 c         0            0.3194        NaN      463.44
# 531            DP Leo b         1            6.0500        NaN    10230.00
# 798      2M 1938+4603 b         1            1.9000        NaN      416.00
#
#      SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 259             3.30           NaN            NaN           NaN
# 261             4.69        0.4000            NaN           NaN
# 501              NaN        0.1701         178.88           NaN
# 531             8.19        0.3900            NaN           NaN
# 798             0.92           NaN            NaN           NaN
#
#      AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 259               NaN             NaN           NaN     NaN          timing
# 261               NaN             NaN           NaN     NaN          timing
# 501               NaN           91.78           NaN     NaN          timing
# 531               NaN             NaN           NaN     NaN          timing
# 798               NaN             NaN           NaN     NaN          timing
#
#      DiscoveryYear LastUpdated  RightAscension     Declination  \
# 259         2011.0    12/12/08        13 38 48       -02 01 49
# 261         2008.0    12/11/24  12 44 20.23731  -08 40 16.8338
# 501         2015.0    15/05/03     19 56 29.39     +41 52 00.3
# 531         2009.0    10/11/18        11 17 16       +17 57 41
# 798         2015.0    15/06/11      19 38 32.6       +46 03 59
#
#      DistFromSunParsec  HostStarMassSlrMass  HostStarRadiusSlrRad  \
# 259             613.18                  NaN                   NaN
# 261             181.00                  NaN                   NaN
# 501                NaN                1.014                 1.122
# 531             400.00                  NaN                   NaN
# 798                NaN                  NaN                   NaN
#
#      HostStarMetallicity  HostStarTempK  HostStarAgeGyr  \
# 259                  NaN            NaN             NaN
# 261                  NaN            NaN             NaN
# 501                -0.01         5820.0             1.0
# 531                  NaN            NaN             NaN
# 798                  NaN            NaN             NaN
#
#                                        ListsPlanetIsOn
# 259  Confirmed planets, Planets in binary systems, ...
# 261   Controversial, Planets in binary systems, P-type
# 501                                  Confirmed planets
# 531  Confirmed planets, Planets in binary systems, ...
# 798  Confirmed planets, Planets in binary systems, ...

# %%
kepler.groupby(['PlanetaryMassJpt']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-16a2722ea6ee> in <module>
# ----> 1 kepler.groupby(['PlanetaryMassJpt']).value_counts()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'
